# %%
import cv2




# Opencv DNN
net = cv2.dnn.readNet("dnn_model/yolov4-tiny.weights", "dnn_model/yolov4-tiny.cfg")
model = cv2.dnn_DetectionModel(net)
model.setInputParams(size=(320, 320), scale=1/255)

# Load class lists
classes = []
with open("dnn_model/classes.txt", "r") as file_object:
    for class_name in file_object.readlines():
        class_name = class_name.strip()
        classes.append(class_name)

print("Objects list")
print(classes)
KNOWN_WIDTH = 20  # Width of the object in real-world units (inches, centimeters, etc.)
FOCAL_LENGTH = 100 


    # Initialize camera
cap = cv2.VideoCapture(0)
cap.set(cv2.CAP_PROP_FRAME_WIDTH, 1280)
cap.set(cv2.CAP_PROP_FRAME_HEIGHT, 720)
# FULL HD 1920 x 1080'''

cv2.namedWindow("Frame")


# Create window

while True:
    # Get frames
    ret, frame = cap.read()

    # Get active buttons list
    #
    #print("Active buttons", active_buttons)

    # Object Detection
    (class_ids, scores, bboxes) = model.detect(frame)
    for class_id, score, bbox in zip(class_ids, scores, bboxes):
        (x,y,w,h) = bbox
        class_name=classes[class_id]
        cv2.putText(frame,(class_name),(x,y-5),cv2.FONT_HERSHEY_PLAIN,2,(255,0,50),2)
        cv2.rectangle(frame,(x,y),(x+w,y+h),(255,0,50),3)
        distance = (KNOWN_WIDTH * FOCAL_LENGTH) / w

        text = f" {distance:.2f} units"  # Modify 'units' to match your real-world units
        cv2.putText(frame, text, (x, y - 20), cv2.FONT_HERSHEY_PLAIN, 0.5, (255, 0, 0), 2)
        cv2.rectangle(frame, (x, y), (x + w, y + h), (0, 255, 0), 2)

        
        print("Class ids", class_id)
        print("Scores", score)
        print("Bboxes", bbox)
        
        

        


    # Display buttons

    cv2.imshow("Frame", frame)
    key = cv2.waitKey(1)
    if key == 27:
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# Objects list
# ['person', 'bicycle', 'car', 'motorbike', 'aeroplane', 'bus', 'train', 'truck', 'boat', 'traffic light', 'fire hydrant', 'stop sign', 'parking meter', 'bench', 'bird', 'cat', 'dog', 'horse', 'sheep', 'cow', 'elephant', 'bear', 'zebra', 'giraffe', 'backpack', 'umbrella', 'handbag', 'tie', 'suitcase', 'frisbee', 'skis', 'snowboard', 'sports ball', 'kite', 'baseball bat', 'baseball glove', 'skateboard', 'surfboard', 'tennis racket', 'bottle', 'wine glass', 'cup', 'fork', 'knife', 'spoon', 'bowl', 'banana', 'apple', 'sandwich', 'orange', 'broccoli', 'carrot', 'hot dog', 'pizza', 'donut', 'cake', 'chair', 'sofa', 'pottedplant', 'bed', 'diningtable', 'toilet', 'tvmonitor', 'laptop', 'mouse', 'remote', 'keyboard', 'cell phone', 'microwave', 'oven', 'toaster', 'sink', 'refrigerator', 'book', 'clock', 'vase', 'scissors', 'teddy bear', 'hair drier', 'toothbrush']
# Class ids 0
# Scores 0.6080069
# Bboxes [114  77 362 629]
# Class ids 0
# Scores 0.84945655
# Bboxes [117  53 346 663]
# Class ids 0
# Scores 0.84945655
# Bboxes [117  53 346 663]
# Class ids 0
# Scores 0.8302385
# Bboxes [119  66 348 647]
# Class ids 0
# Scores 0.6861961
# Bboxes [119  60 355 652]
# Class ids 0
# Scores 0.6861961
# Bboxes [119  60 355 652]
# Class ids 0
# Scores 0.79675096
# Bboxes [107  71 367 639]
# Class ids 0
# Scores 0.8624935
# Bboxes [110  71 359 635]
# Class ids 0
# Scores 0.8624935
# Bboxes [110  71 359 635]
# Class ids 0
# Scores 0.8767092
# Bboxes [ 98  72 375 638]
# Class ids 0
# Scores 0.9150078
# Bboxes [114  76 362 636]
# Class ids 0
# Scores 0.9150078
# Bboxes [114  76 362 636]
# Class ids 0
# Scores 0.901304
# Bboxes [123  67 354 649]
# Class ids 0
# Scores 0.901304
# Bboxes [123  67 354 649]
# Class ids 0
# Scores 0.8118695
# Bboxes [112  69 375 643]
# Class ids 0
# Scores 0.8118695
# Bboxes [112  69 375 643]
# Class ids 0
# Scores 0.7681537
# Bboxes [120  84 356 625]
# Class ids 0
# Scores 0.56386685
# Bboxes [192 308 593 412]
# Class ids 0
# Scores 0.83573866
# Bboxes [272 315 539 403]
# Class ids 0
# Scores 0.56386685
# Bboxes [192 308 593 412]
# Class ids 0
# Scores 0.83573866
# Bboxes [272 315 539 403]
# Class ids 0
# Scores 0.9549541
# Bboxes [244 312 594 406]
# Class ids 0
# Scores 0.9549541
# Bboxes [244 312 594 406]
# Class ids 0
# Scores 0.9701774
# Bboxes [267 322 571 396]
# Class ids 0
# Scores 0.9506365
# Bboxes [260 315 586 405]
# Class ids 0
# Scores 0.9506365
# Bboxes [260 315 586 405]
# Class ids 0
# Scores 0.9204914
# Bboxes [255 313 604 407]
# Class ids 56
# Scores 0.5062969
# Bboxes [965 471 310 249]
# Class ids 0
# Scores 0.94617826
# Bboxes [274 322 566 398]
# Class ids 56
# Scores 0.5628393
# Bboxes [944 478 329 242]
# Class ids 0
# Scores 0.94617826
# Bboxes [274 322 566 398]
# Class ids 56
# Scores 0.5628393
# Bboxes [944 478 329 242]
# Class ids 0
# Scores 0.9555835
# Bboxes [279 319 547 401]
# Class ids 0
# Scores 0.9555835
# Bboxes [279 319 547 401]
# Class ids 0
# Scores 0.961608
# Bboxes [278 311 548 409]
# Class ids 0
# Scores 0.93892354
# Bboxes [273 313 555 407]
# Class ids 0
# Scores 0.93892354
# Bboxes [273 313 555 407]
# Class ids 0
# Scores 0.9524382
# Bboxes [279 309 528 411]
# Class ids 0
# Scores 0.96416485
# Bboxes [287 311 537 409]
# Class ids 0
# Scores 0.96416485
# Bboxes [287 311 537 409]
# Class ids 0
# Scores 0.95662206
# Bboxes [282 310 527 410]
# Class ids 0
# Scores 0.95662206
# Bboxes [282 310 527 410]
# Class ids 0
# Scores 0.95442724
# Bboxes [280 315 534 405]
# Class ids 0
# Scores 0.94734347
# Bboxes [283 310 536 410]
# Class ids 0
# Scores 0.94734347
# Bboxes [283 310 536 410]
# Class ids 0
# Scores 0.891522
# Bboxes [278 318 528 402]
# Class ids 0
# Scores 0.891522
# Bboxes [278 318 528 402]
# Class ids 0
# Scores 0.9537623
# Bboxes [292 318 511 402]
# Class ids 0
# Scores 0.9537623
# Bboxes [292 318 511 402]
# Class ids 0
# Scores 0.93571043
# Bboxes [279 307 554 413]
# Class ids 0
# Scores 0.9641799
# Bboxes [281 306 558 414]
# Class ids 0
# Scores 0.90549374
# Bboxes [284 306 538 414]
# Class ids 56
# Scores 0.5740282
# Bboxes [960 488 294 230]
# Class ids 56
# Scores 0.54021496
# Bboxes [949 474 331 234]
# Class ids 0
# Scores 0.90549374
# Bboxes [284 306 538 414]
# Class ids 56
# Scores 0.5740282
# Bboxes [960 488 294 230]
# Class ids 56
# Scores 0.54021496
# Bboxes [949 474 331 234]
# Class ids 0
# Scores 0.96391064
# Bboxes [283 306 550 414]
# Class ids 0
# Scores 0.9336815
# Bboxes [280 308 565 412]
# Class ids 0
# Scores 0.9336815
# Bboxes [280 308 565 412]
# Class ids 0
# Scores 0.97550625
# Bboxes [285 323 562 393]
# Class ids 0
# Scores 0.97550625
# Bboxes [285 323 562 393]
# Class ids 0
# Scores 0.96871656
# Bboxes [288 311 558 406]
# Class ids 0
# Scores 0.9699306
# Bboxes [297 328 549 386]
# Class ids 0
# Scores 0.9699306
# Bboxes [297 328 549 386]
# Class ids 0
# Scores 0.9624287
# Bboxes [296 315 551 404]
# Class ids 0
# Scores 0.9624287
# Bboxes [296 315 551 404]
# Class ids 0
# Scores 0.98338234
# Bboxes [310 327 535 390]
# Class ids 0
# Scores 0.96979797
# Bboxes [297 313 549 406]
# Class ids 0
# Scores 0.96979797
# Bboxes [297 313 549 406]
# Class ids 0
# Scores 0.9812342
# Bboxes [308 318 537 402]
# Class ids 0
# Scores 0.97735596
# Bboxes [298 313 553 406]
# Class ids 0
# Scores 0.972787
# Bboxes [308 322 527 394]
# Class ids 0
# Scores 0.972787
# Bboxes [308 322 527 394]
# Class ids 0
# Scores 0.9636297
# Bboxes [294 315 555 400]
# Class ids 0
# Scores 0.9636297
# Bboxes [294 315 555 400]
# Class ids 0
# Scores 0.9688245
# Bboxes [291 320 565 398]
# Class ids 0
# Scores 0.95985866
# Bboxes [299 316 551 403]
# Class ids 0
# Scores 0.95985866
# Bboxes [299 316 551 403]
# Class ids 0
# Scores 0.9732158
# Bboxes [293 313 549 407]
# Class ids 0
# Scores 0.96397644
# Bboxes [292 312 562 408]
# Class ids 0
# Scores 0.96397644
# Bboxes [292 312 562 408]
# Class ids 0
# Scores 0.9747111
# Bboxes [281 321 572 397]
# Class ids 0
# Scores 0.98382896
# Bboxes [284 314 571 406]
# Class ids 0
# Scores 0.98382896
# Bboxes [284 314 571 406]
# Class ids 0
# Scores 0.9800441
# Bboxes [272 318 585 402]
# Class ids 0
# Scores 0.9843834
# Bboxes [279 321 562 398]
# Class ids 0
# Scores 0.9843834
# Bboxes [279 321 562 398]
# Class ids 0
# Scores 0.9787097
# Bboxes [292 320 555 400]
# Class ids 0
# Scores 0.9808817
# Bboxes [292 319 552 401]
# Class ids 0
# Scores 0.9808817
# Bboxes [292 319 552 401]
# Class ids 0
# Scores 0.97460437
# Bboxes [280 319 563 399]
# Class ids 0
# Scores 0.9723168
# Bboxes [277 317 570 403]
# Class ids 0
# Scores 0.9810865
# Bboxes [287 323 559 397]
# Class ids 0
# Scores 0.9806997
# Bboxes [281 318 564 402]
# Class ids 0
# Scores 0.9759543
# Bboxes [271 319 592 401]
# Class ids 0
# Scores 0.98398674
# Bboxes [275 321 577 399]
# Class ids 0
# Scores 0.9829125
# Bboxes [281 322 566 398]
# Class ids 0
# Scores 0.97807217
# Bboxes [269 315 588 405]
# Class ids 0
# Scores 0.9779637
# Bboxes [269 316 577 404]
# Class ids 0
# Scores 0.9796743
# Bboxes [275 318 574 402]
# Class ids 0
# Scores 0.9737885
# Bboxes [245 318 620 402]
# Class ids 0
# Scores 0.97159797
# Bboxes [249 318 619 402]
# Class ids 0
# Scores 0.98116654
# Bboxes [247 315 610 405]
# Class ids 0
# Scores 0.9692355
# Bboxes [229 319 634 401]
# Class ids 0
# Scores 0.9779085
# Bboxes [238 319 642 401]
# Class ids 0
# Scores 0.9824104
# Bboxes [240 317 643 403]
# Class ids 0
# Scores 0.98478997
# Bboxes [246 325 636 395]
# Class ids 0
# Scores 0.9827288
# Bboxes [250 320 648 400]
# Class ids 0
# Scores 0.97869974
# Bboxes [257 325 638 395]
# Class ids 0
# Scores 0.9796752
# Bboxes [258 324 642 396]
# Class ids 0
# Scores 0.5010517
# Bboxes [908 465 155 170]
# Class ids 0
# Scores 0.9806998
# Bboxes [249 325 643 395]
# Class ids 0
# Scores 0.98511857
# Bboxes [248 325 648 395]
# Class ids 0
# Scores 0.97179526
# Bboxes [247 321 624 399]
# Class ids 0
# Scores 0.52233624
# Bboxes [912 469 149 164]
# Class ids 0
# Scores 0.97841233
# Bboxes [254 321 622 399]
# Class ids 0
# Scores 0.5031734
# Bboxes [910 468 150 165]
# Class ids 0
# Scores 0.9752181
# Bboxes [250 319 628 401]
# Class ids 0
# Scores 0.50356823
# Bboxes [909 468 152 166]
# Class ids 0
# Scores 0.97534055
# Bboxes [259 320 616 400]
# Class ids 0
# Scores 0.9704287
# Bboxes [247 321 633 399]
# Class ids 0
# Scores 0.9776754
# Bboxes [262 315 602 405]
# Class ids 0
# Scores 0.97877485
# Bboxes [255 315 619 405]
# Class ids 0
# Scores 0.956318
# Bboxes [263 315 616 401]
# Class ids 0
# Scores 0.93488276
# Bboxes [267 317 612 399]
# Class ids 0
# Scores 0.59598315
# Bboxes [911 468 154 169]
# Class ids 0
# Scores 0.9451623
# Bboxes [264 313 621 404]
# Class ids 0
# Scores 0.50724643
# Bboxes [913 470 149 165]
# Class ids 0
# Scores 0.9383436
# Bboxes [304 312 593 407]
# Class ids 0
# Scores 0.59715
# Bboxes [911 468 152 169]
# Class ids 0
# Scores 0.91875005
# Bboxes [297 310 594 410]
# Class ids 0
# Scores 0.9454572
# Bboxes [306 313 578 406]
# Class ids 0
# Scores 0.5629449
# Bboxes [911 469 155 168]
# Class ids 0
# Scores 0.9252233
# Bboxes [292 320 612 400]
# Class ids 0
# Scores 0.9477603
# Bboxes [303 323 601 397]
# Class ids 0
# Scores 0.94793355
# Bboxes [298 320 603 400]
# Class ids 0
# Scores 0.95315915
# Bboxes [304 322 593 394]
# Class ids 0
# Scores 0.95561004
# Bboxes [308 322 570 392]
# Class ids 0
# Scores 0.9529166
# Bboxes [306 321 579 394]
# Class ids 0
# Scores 0.95699024
# Bboxes [311 321 577 393]
# Class ids 0
# Scores 0.94823015
# Bboxes [317 322 559 393]
# Class ids 0
# Scores 0.95919704
# Bboxes [310 321 568 392]
# Class ids 0
# Scores 0.96038413
# Bboxes [312 322 560 393]
# Class ids 0
# Scores 0.9712628
# Bboxes [287 321 583 393]
# Class ids 0
# Scores 0.9696127
# Bboxes [271 323 603 389]
# Class ids 0
# Scores 0.9656156
# Bboxes [279 320 595 393]
# Class ids 0
# Scores 0.9635456
# Bboxes [270 320 594 393]
# Class ids 0
# Scores 0.92837816
# Bboxes [324 319 523 398]
# Class ids 0
# Scores 0.9048322
# Bboxes [349 325 505 389]
# Class ids 0
# Scores 0.7543816
# Bboxes [282 316 567 396]
# Class ids 0
# Scores 0.50601995
# Bboxes [336 318 509 392]
# Class ids 0
# Scores 0.66131544
# Bboxes [479 321 398 395]
# Class ids 0
# Scores 0.53921145
# Bboxes [250 252 343 446]
# Class ids 0
# Scores 0.6266032
# Bboxes [527 332 334 383]
# Class ids 67
# Scores 0.5946498
# Bboxes [460 236 207 345]
# Class ids 67
# Scores 0.5429297
# Bboxes [453 239 214 341]
# Class ids 0
# Scores 0.5593421
# Bboxes [478 335 407 379]
# Class ids 0
# Scores 0.5468572
# Bboxes [499 335 385 382]
# Class ids 0
# Scores 0.5903157
# Bboxes [486 331 393 384]
# Class ids 0
# Scores 0.52437544
# Bboxes [499 332 387 384]
# Class ids 0
# Scores 0.50799143
# Bboxes [496 329 397 387]
# Class ids 0
# Scores 0.50799143
# Bboxes [496 329 397 387]
# Class ids 0
# Scores 0.60428494
# Bboxes [507 328 383 388]
# Class ids 0
# Scores 0.60428494
# Bboxes [507 328 383 388]
# Class ids 0
# Scores 0.52743053
# Bboxes [539 313 345 407]
# Class ids 0
# Scores 0.60628533
# Bboxes [372 263 399 448]
# Class ids 65
# Scores 0.5685339
# Bboxes [425 262 194 364]
# Class ids 0
# Scores 0.60628533
# Bboxes [372 263 399 448]
# Class ids 65
# Scores 0.5685339
# Bboxes [425 262 194 364]
# Class ids 0
# Scores 0.84166867
# Bboxes [320 251 526 469]
# Class ids 0
# Scores 0.84166867
# Bboxes [320 251 526 469]
# Class ids 0
# Scores 0.8854155
# Bboxes [313 229 539 491]
# Class ids 0
# Scores 0.7763953
# Bboxes [325 210 532 500]
# Class ids 0
# Scores 0.7763953
# Bboxes [325 210 532 500]
# Class ids 0
# Scores 0.7441478
# Bboxes [319 166 555 554]
# Class ids 0
# Scores 0.5176105
# Bboxes [954 251 326 468]
# Class ids 0
# Scores 0.59164095
# Bboxes [960 231 320 489]
# Class ids 0
# Scores 0.5325075
# Bboxes [943 223 337 492]
# Class ids 0
# Scores 0.5325075
# Bboxes [943 223 337 492]
# Class ids 0
# Scores 0.75760657
# Bboxes [302  90 564 621]
# Class ids 15
# Scores 0.6084183
# Bboxes [893 271 310 151]
# Class ids 0
# Scores 0.59815186
# Bboxes [580 111 304 607]
# Class ids 0
# Scores 0.59815186
# Bboxes [580 111 304 607]
# Class ids 0
# Scores 0.7536283
# Bboxes [295 110 553 608]
# Class ids 0
# Scores 0.6592461
# Bboxes [952 244 328 475]
# Class ids 0
# Scores 0.81888765
# Bboxes [259 130 594 580]
# Class ids 0
# Scores 0.51783085
# Bboxes [948 255 332 460]
# Class ids 0
# Scores 0.81888765
# Bboxes [259 130 594 580]
# Class ids 0
# Scores 0.51783085
# Bboxes [948 255 332 460]
# Class ids 0
# Scores 0.87693423
# Bboxes [244 145 620 563]
# Class ids 0
# Scores 0.881006
# Bboxes [254 168 633 542]
# Class ids 0
# Scores 0.87693423
# Bboxes [244 145 620 563]
# Class ids 0
# Scores 0.881006
# Bboxes [254 168 633 542]
# Class ids 0
# Scores 0.68178225
# Bboxes [259 154 603 541]
# Class ids 0
# Scores 0.9498848
# Bboxes [227 160 674 559]
# Class ids 0
# Scores 0.8139178
# Bboxes [268 133 594 577]
# Class ids 0
# Scores 0.92700696
# Bboxes [248 158 619 562]
# Class ids 0
# Scores 0.8139178
# Bboxes [268 133 594 577]
# Class ids 0
# Scores 0.92700696
# Bboxes [248 158 619 562]
# Class ids 0
# Scores 0.6192361
# Bboxes [271 146 583 551]
# Class ids 0
# Scores 0.95921266
# Bboxes [257 175 613 538]
# Class ids 39
# Scores 0.67026955
# Bboxes [456 448 214 272]
# Class ids 0
# Scores 0.66035205
# Bboxes [249 155 614 537]
# Class ids 0
# Scores 0.9617184
# Bboxes [242 177 623 535]
# Class ids 0
# Scores 0.67464566
# Bboxes [968 251 312 469]
# Class ids 39
# Scores 0.6008254
# Bboxes [464 441 197 279]
# Class ids 0
# Scores 0.66035205
# Bboxes [249 155 614 537]
# Class ids 0
# Scores 0.9617184
# Bboxes [242 177 623 535]
# Class ids 0
# Scores 0.67464566
# Bboxes [968 251 312 469]
# Class ids 39
# Scores 0.6008254
# Bboxes [464 441 197 279]
# Class ids 0
# Scores 0.73705214
# Bboxes [270 145 597 553]
# Class ids 0
# Scores 0.8251359
# Bboxes [257 171 616 536]
# Class ids 0
# Scores 0.73705214
# Bboxes [270 145 597 553]
# Class ids 0
# Scores 0.8251359
# Bboxes [257 171 616 536]
# Class ids 0
# Scores 0.93934524
# Bboxes [259 134 611 562]
# Class ids 0
# Scores 0.9443926
# Bboxes [282 118 577 579]
# Class ids 0
# Scores 0.9443926
# Bboxes [282 118 577 579]
# Class ids 0
# Scores 0.501745
# Bboxes [146   5 628 642]
# Class ids 39
# Scores 0.6710492
# Bboxes [273 319 317 395]
# Class ids 0
# Scores 0.501745
# Bboxes [146   5 628 642]
# Class ids 39
# Scores 0.6710492
# Bboxes [273 319 317 395]
# Class ids 39
# Scores 0.6573978
# Bboxes [259 315 305 395]
# Class ids 39
# Scores 0.53121454
# Bboxes [255 313 214 331]
# Class ids 39
# Scores 0.60671127
# Bboxes [224 322 277 391]
# Class ids 39
# Scores 0.53121454
# Bboxes [255 313 214 331]
# Class ids 39
# Scores 0.60671127
# Bboxes [224 322 277 391]
# Class ids 39
# Scores 0.7224953
# Bboxes [219 306 267 409]
# Class ids 39
# Scores 0.7224953
# Bboxes [219 306 267 409]
# Class ids 39
# Scores 0.75112414
# Bboxes [165 327 300 387]
# Class ids 39
# Scores 0.5611172
# Bboxes [214 324 205 389]
# Class ids 39
# Scores 0.79781616
# Bboxes [185 314 269 404]
# Class ids 39
# Scores 0.5611172
# Bboxes [214 324 205 389]
# Class ids 39
# Scores 0.79781616
# Bboxes [185 314 269 404]
# Class ids 0
# Scores 0.60877824
# Bboxes [ 21  50 512 598]
# Class ids 0
# Scores 0.5962839
# Bboxes [667   3 372 641]
# Class ids 0
# Scores 0.5084819
# Bboxes [673   7 532 641]
# Class ids 0
# Scores 0.6185056
# Bboxes [ 20  62 511 632]
# Class ids 0
# Scores 0.6185056
# Bboxes [ 20  62 511 632]
# Class ids 39
# Scores 0.57797956
# Bboxes [258 291 307 406]
# Class ids 39
# Scores 0.71870375
# Bboxes [249 307 309 409]
# Class ids 39
# Scores 0.75026417
# Bboxes [430 330 328 388]
# Class ids 0
# Scores 0.5893053
# Bboxes [  1  29 483 691]
# Class ids 0
# Scores 0.51044726
# Bboxes [  5  40 522 680]
# Class ids 39
# Scores 0.6496491
# Bboxes [502 331 214 389]
# Class ids 39
# Scores 0.9405511
# Bboxes [473 328 274 389]
# Class ids 0
# Scores 0.5893053
# Bboxes [  1  29 483 691]
# Class ids 0
# Scores 0.51044726
# Bboxes [  5  40 522 680]
# Class ids 39
# Scores 0.6496491
# Bboxes [502 331 214 389]
# Class ids 39
# Scores 0.9405511
# Bboxes [473 328 274 389]
# Class ids 39
# Scores 0.77065814
# Bboxes [505 323 214 397]
# Class ids 39
# Scores 0.9756243
# Bboxes [480 321 267 399]
# Class ids 39
# Scores 0.6075658
# Bboxes [502 339 227 376]
# Class ids 39
# Scores 0.77065814
# Bboxes [505 323 214 397]
# Class ids 39
# Scores 0.9756243
# Bboxes [480 321 267 399]
# Class ids 39
# Scores 0.6075658
# Bboxes [502 339 227 376]
# Class ids 0
# Scores 0.5648332
# Bboxes [676   0 358 645]
# Class ids 39
# Scores 0.87663424
# Bboxes [501 327 229 393]
# Class ids 39
# Scores 0.986286
# Bboxes [476 333 280 384]
# Class ids 39
# Scores 0.5975074
# Bboxes [501 347 232 360]
# Class ids 0
# Scores 0.5648332
# Bboxes [676   0 358 645]
# Class ids 39
# Scores 0.87663424
# Bboxes [501 327 229 393]
# Class ids 39
# Scores 0.986286
# Bboxes [476 333 280 384]
# Class ids 39
# Scores 0.5975074
# Bboxes [501 347 232 360]
# Class ids 0
# Scores 0.60071146
# Bboxes [671   0 360 643]
# Class ids 0
# Scores 0.665815
# Bboxes [  0  40 499 671]
# Class ids 39
# Scores 0.8655617
# Bboxes [495 320 231 400]
# Class ids 39
# Scores 0.9900705
# Bboxes [464 335 289 379]
# Class ids 39
# Scores 0.80399066
# Bboxes [498 339 235 373]
# Class ids 0
# Scores 0.6225744
# Bboxes [681   0 346 642]
# Class ids 0
# Scores 0.70704114
# Bboxes [  0  40 497 670]
# Class ids 39
# Scores 0.89283544
# Bboxes [501 319 227 401]
# Class ids 39
# Scores 0.9890022
# Bboxes [476 333 281 383]
# Class ids 39
# Scores 0.64710796
# Bboxes [500 337 233 377]
# Class ids 0
# Scores 0.6225744
# Bboxes [681   0 346 642]
# Class ids 0
# Scores 0.70704114
# Bboxes [  0  40 497 670]
# Class ids 39
# Scores 0.89283544
# Bboxes [501 319 227 401]
# Class ids 39
# Scores 0.9890022
# Bboxes [476 333 281 383]
# Class ids 39
# Scores 0.64710796
# Bboxes [500 337 233 377]
# Class ids 0
# Scores 0.62370783
# Bboxes [675   0 354 655]
# Class ids 0
# Scores 0.64201397
# Bboxes [  0  38 493 676]
# Class ids 39
# Scores 0.8864865
# Bboxes [497 323 230 397]
# Class ids 39
# Scores 0.9838684
# Bboxes [465 339 296 375]
# Class ids 39
# Scores 0.6046483
# Bboxes [499 341 232 370]
# Class ids 0
# Scores 0.62370783
# Bboxes [675   0 354 655]
# Class ids 0
# Scores 0.64201397
# Bboxes [  0  38 493 676]
# Class ids 39
# Scores 0.8864865
# Bboxes [497 323 230 397]
# Class ids 39
# Scores 0.9838684
# Bboxes [465 339 296 375]
# Class ids 39
# Scores 0.6046483
# Bboxes [499 341 232 370]
# Class ids 0
# Scores 0.51700395
# Bboxes [680   0 362 649]
# Class ids 39
# Scores 0.8708831
# Bboxes [497 321 228 399]
# Class ids 39
# Scores 0.98308873
# Bboxes [465 333 295 382]
# Class ids 39
# Scores 0.8009064
# Bboxes [498 343 234 363]
# Class ids 0
# Scores 0.51700395
# Bboxes [680   0 362 649]
# Class ids 39
# Scores 0.8708831
# Bboxes [497 321 228 399]
# Class ids 39
# Scores 0.98308873
# Bboxes [465 333 295 382]
# Class ids 39
# Scores 0.8009064
# Bboxes [498 343 234 363]
# Class ids 0
# Scores 0.5661151
# Bboxes [674   0 330 658]
# Class ids 39
# Scores 0.8844774
# Bboxes [501 323 229 397]
# Class ids 39
# Scores 0.994187
# Bboxes [479 334 279 384]
# Class ids 39
# Scores 0.5323781
# Bboxes [502 335 233 385]
# Class ids 0
# Scores 0.50794
# Bboxes [  0  31 491 689]
# Class ids 39
# Scores 0.6467097
# Bboxes [495 328 232 392]
# Class ids 39
# Scores 0.9750267
# Bboxes [466 323 295 392]
# Class ids 0
# Scores 0.50794
# Bboxes [  0  31 491 689]
# Class ids 39
# Scores 0.6467097
# Bboxes [495 328 232 392]
# Class ids 39
# Scores 0.9750267
# Bboxes [466 323 295 392]
# Class ids 39
# Scores 0.5783633
# Bboxes [503 320 220 400]
# Class ids 39
# Scores 0.9671722
# Bboxes [478 320 281 393]
# Class ids 39
# Scores 0.5371604
# Bboxes [507 335 225 374]
# Class ids 39
# Scores 0.7572366
# Bboxes [479 278 278 434]
# Class ids 39
# Scores 0.894926
# Bboxes [488 305 271 414]
# Class ids 39
# Scores 0.7572366
# Bboxes [479 278 278 434]
# Class ids 39
# Scores 0.894926
# Bboxes [488 305 271 414]
# Class ids 0
# Scores 0.62920403
# Bboxes [  0   8 486 658]
# Class ids 39
# Scores 0.58165777
# Bboxes [479 277 282 430]
# Class ids 39
# Scores 0.8838817
# Bboxes [488 314 274 402]
# Class ids 0
# Scores 0.6116628
# Bboxes [  0  14 494 653]
# Class ids 39
# Scores 0.951289
# Bboxes [489 317 274 398]
# Class ids 0
# Scores 0.6116628
# Bboxes [  0  14 494 653]
# Class ids 39
# Scores 0.951289
# Bboxes [489 317 274 398]
# Class ids 0
# Scores 0.58546954
# Bboxes [  0  20 479 640]
# Class ids 0
# Scores 0.6223309
# Bboxes [  0  19 488 701]
# Class ids 39
# Scores 0.86408734
# Bboxes [482 276 273 432]
# Class ids 39
# Scores 0.86254257
# Bboxes [483 310 279 406]
# Class ids 39
# Scores 0.91215986
# Bboxes [490 275 270 438]
# Class ids 39
# Scores 0.90107274
# Bboxes [483 302 283 418]
# Class ids 39
# Scores 0.91215986
# Bboxes [490 275 270 438]
# Class ids 39
# Scores 0.90107274
# Bboxes [483 302 283 418]
# Class ids 39
# Scores 0.7561878
# Bboxes [485 270 282 440]
# Class ids 39
# Scores 0.76486266
# Bboxes [484 315 292 401]
# Class ids 0
# Scores 0.6715743
# Bboxes [  0  16 486 655]
# Class ids 0
# Scores 0.6248489
# Bboxes [  0  32 489 686]
# Class ids 39
# Scores 0.7191381
# Bboxes [490 283 270 423]
# Class ids 39
# Scores 0.8677979
# Bboxes [495 302 271 417]
# Class ids 0
# Scores 0.6715743
# Bboxes [  0  16 486 655]
# Class ids 0
# Scores 0.6248489
# Bboxes [  0  32 489 686]
# Class ids 39
# Scores 0.7191381
# Bboxes [490 283 270 423]
# Class ids 39
# Scores 0.8677979
# Bboxes [495 302 271 417]
# Class ids 39
# Scores 0.9112969
# Bboxes [490 273 269 442]
# Class ids 39
# Scores 0.8016244
# Bboxes [488 303 283 415]
# Class ids 39
# Scores 0.9112969
# Bboxes [490 273 269 442]
# Class ids 39
# Scores 0.8016244
# Bboxes [488 303 283 415]
# Class ids 0
# Scores 0.5897736
# Bboxes [714   6 319 498]
# Class ids 0
# Scores 0.52511114
# Bboxes [  0  15 488 650]
# Class ids 39
# Scores 0.8865175
# Bboxes [494 271 266 446]
# Class ids 39
# Scores 0.86355305
# Bboxes [496 296 270 424]
# Class ids 0
# Scores 0.5897736
# Bboxes [714   6 319 498]
# Class ids 0
# Scores 0.52511114
# Bboxes [  0  15 488 650]
# Class ids 39
# Scores 0.8865175
# Bboxes [494 271 266 446]
# Class ids 39
# Scores 0.86355305
# Bboxes [496 296 270 424]
# Class ids 0
# Scores 0.59456724
# Bboxes [  0  23 494 638]
# Class ids 0
# Scores 0.69230974
# Bboxes [  0  32 508 688]
# Class ids 39
# Scores 0.70435536
# Bboxes [487 284 274 427]
# Class ids 39
# Scores 0.97177917
# Bboxes [502 300 259 420]
# Class ids 0
# Scores 0.7992099
# Bboxes [476 162 128 157]
# Class ids 0
# Scores 0.7363641
# Bboxes [  0  16 476 645]
# Class ids 0
# Scores 0.5123896
# Bboxes [  0  30 484 690]
# Class ids 39
# Scores 0.8932087
# Bboxes [485 283 272 429]
# Class ids 39
# Scores 0.89955074
# Bboxes [493 298 270 422]
# Class ids 0
# Scores 0.7777139
# Bboxes [474 152 130 160]
# Class ids 0
# Scores 0.7363641
# Bboxes [  0  16 476 645]
# Class ids 0
# Scores 0.5123896
# Bboxes [  0  30 484 690]
# Class ids 39
# Scores 0.8932087
# Bboxes [485 283 272 429]
# Class ids 39
# Scores 0.89955074
# Bboxes [493 298 270 422]
# Class ids 0
# Scores 0.7777139
# Bboxes [474 152 130 160]
# Class ids 0
# Scores 0.5678827
# Bboxes [  0  25 488 637]
# Class ids 0
# Scores 0.6053754
# Bboxes [  0  33 502 687]
# Class ids 39
# Scores 0.7756171
# Bboxes [473 290 282 419]
# Class ids 39
# Scores 0.95826304
# Bboxes [490 304 273 415]
# Class ids 0
# Scores 0.6812922
# Bboxes [478 158 141 157]
# Class ids 0
# Scores 0.576716
# Bboxes [  0  28 502 635]
# Class ids 0
# Scores 0.5963904
# Bboxes [  0  34 512 685]
# Class ids 39
# Scores 0.88050485
# Bboxes [491 286 269 421]
# Class ids 39
# Scores 0.9048789
# Bboxes [495 302 271 416]
# Class ids 0
# Scores 0.6846208
# Bboxes [481 164 132 155]
# Class ids 0
# Scores 0.576716
# Bboxes [  0  28 502 635]
# Class ids 0
# Scores 0.5963904
# Bboxes [  0  34 512 685]
# Class ids 39
# Scores 0.88050485
# Bboxes [491 286 269 421]
# Class ids 39
# Scores 0.9048789
# Bboxes [495 302 271 416]
# Class ids 0
# Scores 0.6846208
# Bboxes [481 164 132 155]
# Class ids 0
# Scores 0.6497417
# Bboxes [  0  34 505 686]
# Class ids 39
# Scores 0.73953134
# Bboxes [488 292 268 410]
# Class ids 39
# Scores 0.9477762
# Bboxes [502 305 257 413]
# Class ids 0
# Scores 0.6915536
# Bboxes [483 162 135 158]
# Class ids 0
# Scores 0.6497417
# Bboxes [  0  34 505 686]
# Class ids 39
# Scores 0.73953134
# Bboxes [488 292 268 410]
# Class ids 39
# Scores 0.9477762
# Bboxes [502 305 257 413]
# Class ids 0
# Scores 0.6915536
# Bboxes [483 162 135 158]
# Class ids 0
# Scores 0.59620535
# Bboxes [  3  12 468 653]
# Class ids 39
# Scores 0.8145425
# Bboxes [492 285 262 420]
# Class ids 39
# Scores 0.89207405
# Bboxes [497 300 265 420]
# Class ids 0
# Scores 0.5222133
# Bboxes [  6   4 459 671]
# Class ids 39
# Scores 0.95186204
# Bboxes [495 276 265 437]
# Class ids 39
# Scores 0.6030152
# Bboxes [506 276 277 436]
# Class ids 39
# Scores 0.85621595
# Bboxes [484 298 288 421]
# Class ids 0
# Scores 0.5222133
# Bboxes [  6   4 459 671]
# Class ids 39
# Scores 0.95186204
# Bboxes [495 276 265 437]
# Class ids 39
# Scores 0.6030152
# Bboxes [506 276 277 436]
# Class ids 39
# Scores 0.85621595
# Bboxes [484 298 288 421]
# Class ids 39
# Scores 0.9696724
# Bboxes [501 257 261 460]
# Class ids 39
# Scores 0.8383155
# Bboxes [507 257 278 462]
# Class ids 39
# Scores 0.9696724
# Bboxes [501 257 261 460]
# Class ids 39
# Scores 0.8383155
# Bboxes [507 257 278 462]
# Class ids 39
# Scores 0.9687223
# Bboxes [500 216 265 504]
# Class ids 39
# Scores 0.8813814
# Bboxes [499 223 297 497]
# Class ids 39
# Scores 0.9687223
# Bboxes [500 216 265 504]
# Class ids 39
# Scores 0.8813814
# Bboxes [499 223 297 497]
# Class ids 39
# Scores 0.96437913
# Bboxes [496 208 269 512]
# Class ids 39
# Scores 0.96437913
# Bboxes [496 208 269 512]
# Class ids 39
# Scores 0.95768154
# Bboxes [501 213 259 507]
# Class ids 73
# Scores 0.5094056
# Bboxes [1087  549  193   99]
# Class ids 0
# Scores 0.51584035
# Bboxes [704   0 369 490]
# Class ids 0
# Scores 0.5213282
# Bboxes [721   0 425 515]
# Class ids 39
# Scores 0.9653151
# Bboxes [496 217 271 498]
# Class ids 0
# Scores 0.51584035
# Bboxes [704   0 369 490]
# Class ids 0
# Scores 0.5213282
# Bboxes [721   0 425 515]
# Class ids 39
# Scores 0.9653151
# Bboxes [496 217 271 498]
# Class ids 0
# Scores 0.6900097
# Bboxes [741   0 345 498]
# Class ids 39
# Scores 0.98198307
# Bboxes [505 213 255 498]
# Class ids 39
# Scores 0.61800486
# Bboxes [489 209 314 499]
# Class ids 39
# Scores 0.974332
# Bboxes [501 210 262 503]
# Class ids 39
# Scores 0.641627
# Bboxes [492 202 309 511]
# Class ids 39
# Scores 0.974332
# Bboxes [501 210 262 503]
# Class ids 39
# Scores 0.641627
# Bboxes [492 202 309 511]
# Class ids 39
# Scores 0.9494088
# Bboxes [494 215 277 498]
# Class ids 39
# Scores 0.8169435
# Bboxes [492 202 311 516]
# Class ids 39
# Scores 0.9004902
# Bboxes [495 215 278 487]
# Class ids 39
# Scores 0.73482794
# Bboxes [493 202 307 513]
# Class ids 39
# Scores 0.9004902
# Bboxes [495 215 278 487]
# Class ids 39
# Scores 0.73482794
# Bboxes [493 202 307 513]
# Class ids 39
# Scores 0.92831033
# Bboxes [493 219 281 486]
# Class ids 39
# Scores 0.82732725
# Bboxes [490 221 315 489]
# Class ids 39
# Scores 0.92831033
# Bboxes [493 219 281 486]
# Class ids 39
# Scores 0.82732725
# Bboxes [490 221 315 489]
# Class ids 39
# Scores 0.9043898
# Bboxes [499 223 271 493]
# Class ids 39
# Scores 0.5992812
# Bboxes [495 219 303 501]
# Class ids 39
# Scores 0.88808906
# Bboxes [495 215 276 489]
# Class ids 39
# Scores 0.5897535
# Bboxes [491 214 313 496]
# Class ids 39
# Scores 0.88808906
# Bboxes [495 215 276 489]
# Class ids 39
# Scores 0.5897535
# Bboxes [491 214 313 496]
# Class ids 39
# Scores 0.942154
# Bboxes [494 205 281 512]
# Class ids 39
# Scores 0.86165005
# Bboxes [493 206 306 511]
# Class ids 39
# Scores 0.9480453
# Bboxes [496 205 274 512]
# Class ids 39
# Scores 0.8655561
# Bboxes [496 206 302 512]
# Class ids 0
# Scores 0.5102478
# Bboxes [  0   0 489 681]
# Class ids 39
# Scores 0.9409078
# Bboxes [492 206 284 503]
# Class ids 39
# Scores 0.897393
# Bboxes [498 205 296 510]
# Class ids 0
# Scores 0.5371289
# Bboxes [  0   0 496 687]
# Class ids 39
# Scores 0.9233456
# Bboxes [491 209 284 500]
# Class ids 39
# Scores 0.8328093
# Bboxes [492 208 309 508]
# Class ids 39
# Scores 0.93157697
# Bboxes [495 210 277 497]
# Class ids 39
# Scores 0.6831819
# Bboxes [494 210 303 505]
# Class ids 39
# Scores 0.93157697
# Bboxes [495 210 277 497]
# Class ids 39
# Scores 0.6831819
# Bboxes [494 210 303 505]
# Class ids 39
# Scores 0.95456237
# Bboxes [497 213 270 498]
# Class ids 39
# Scores 0.75013936
# Bboxes [495 215 302 498]
# Class ids 39
# Scores 0.9667875
# Bboxes [496 215 272 499]
# Class ids 39
# Scores 0.80615175
# Bboxes [497 217 298 497]
# Class ids 39
# Scores 0.9796144
# Bboxes [501 215 262 501]
# Class ids 39
# Scores 0.9399454
# Bboxes [502 213 287 507]
# Class ids 39
# Scores 0.9796144
# Bboxes [501 215 262 501]
# Class ids 39
# Scores 0.9399454
# Bboxes [502 213 287 507]
# Class ids 39
# Scores 0.9796144
# Bboxes [501 215 262 501]
# Class ids 39
# Scores 0.9399454
# Bboxes [502 213 287 507]
# Class ids 39
# Scores 0.98523283
# Bboxes [502 230 260 483]
# Class ids 39
# Scores 0.94974846
# Bboxes [504 231 287 487]
# Class ids 39
# Scores 0.98118687
# Bboxes [492 238 276 482]
# Class ids 39
# Scores 0.95029795
# Bboxes [504 233 288 487]
# Class ids 39
# Scores 0.98118687
# Bboxes [492 238 276 482]
# Class ids 39
# Scores 0.95029795
# Bboxes [504 233 288 487]
# Class ids 0
# Scores 0.5193117
# Bboxes [698  26 281 453]
# Class ids 39
# Scores 0.97000575
# Bboxes [492 249 275 460]
# Class ids 39
# Scores 0.9581211
# Bboxes [503 243 294 469]
# Class ids 0
# Scores 0.5193117
# Bboxes [698  26 281 453]
# Class ids 39
# Scores 0.97000575
# Bboxes [492 249 275 460]
# Class ids 39
# Scores 0.9581211
# Bboxes [503 243 294 469]
# Class ids 0
# Scores 0.6244811
# Bboxes [690  32 292 444]
# Class ids 39
# Scores 0.9584809
# Bboxes [503 262 256 453]
# Class ids 39
# Scores 0.92350024
# Bboxes [512 255 273 463]
# Class ids 0
# Scores 0.7298781
# Bboxes [650  11 346 464]
# Class ids 39
# Scores 0.9103603
# Bboxes [500 270 263 446]
# Class ids 39
# Scores 0.94306767
# Bboxes [508 269 282 447]
# Class ids 39
# Scores 0.6142297
# Bboxes [468 311 329 403]
# Class ids 0
# Scores 0.7298781
# Bboxes [650  11 346 464]
# Class ids 39
# Scores 0.9103603
# Bboxes [500 270 263 446]
# Class ids 39
# Scores 0.94306767
# Bboxes [508 269 282 447]
# Class ids 39
# Scores 0.6142297
# Bboxes [468 311 329 403]
# Class ids 0
# Scores 0.6615451
# Bboxes [673   1 317 486]
# Class ids 39
# Scores 0.7931555
# Bboxes [490 269 279 448]
# Class ids 39
# Scores 0.8804689
# Bboxes [506 266 291 450]
# Class ids 0
# Scores 0.7567392
# Bboxes [682   0 294 491]
# Class ids 39
# Scores 0.70107716
# Bboxes [492 271 274 442]
# Class ids 39
# Scores 0.8434935
# Bboxes [504 267 292 447]
# Class ids 0
# Scores 0.7567392
# Bboxes [682   0 294 491]
# Class ids 39
# Scores 0.70107716
# Bboxes [492 271 274 442]
# Class ids 39
# Scores 0.8434935
# Bboxes [504 267 292 447]
# Class ids 0
# Scores 0.61837745
# Bboxes [656   0 313 483]
# Class ids 0
# Scores 0.6024233
# Bboxes [  0  17 486 633]
# Class ids 39
# Scores 0.90639615
# Bboxes [496 268 267 446]
# Class ids 39
# Scores 0.90888536
# Bboxes [503 265 291 448]
# Class ids 0
# Scores 0.51660925
# Bboxes [484 131 129 161]
# Class ids 0
# Scores 0.6735219
# Bboxes [660   0 305 489]
# Class ids 39
# Scores 0.9014943
# Bboxes [492 281 269 428]
# Class ids 39
# Scores 0.823529
# Bboxes [502 272 294 442]
# Class ids 39
# Scores 0.6348093
# Bboxes [467 317 328 393]
# Class ids 0
# Scores 0.54621977
# Bboxes [489 132 129 162]
# Class ids 0
# Scores 0.5348703
# Bboxes [487 134 129 168]
# Class ids 0
# Scores 0.6735219
# Bboxes [660   0 305 489]
# Class ids 39
# Scores 0.9014943
# Bboxes [492 281 269 428]
# Class ids 39
# Scores 0.823529
# Bboxes [502 272 294 442]
# Class ids 39
# Scores 0.6348093
# Bboxes [467 317 328 393]
# Class ids 0
# Scores 0.54621977
# Bboxes [489 132 129 162]
# Class ids 0
# Scores 0.5348703
# Bboxes [487 134 129 168]
# Class ids 0
# Scores 0.50136334
# Bboxes [  0  21 486 638]
# Class ids 0
# Scores 0.7441072
# Bboxes [  0  21 497 699]
# Class ids 39
# Scores 0.6690714
# Bboxes [492 285 269 417]
# Class ids 39
# Scores 0.67690074
# Bboxes [473 314 316 400]
# Class ids 0
# Scores 0.50136334
# Bboxes [  0  21 486 638]
# Class ids 0
# Scores 0.7441072
# Bboxes [  0  21 497 699]
# Class ids 39
# Scores 0.6690714
# Bboxes [492 285 269 417]
# Class ids 39
# Scores 0.67690074
# Bboxes [473 314 316 400]
# Class ids 0
# Scores 0.5767887
# Bboxes [  0  22 485 634]
# Class ids 0
# Scores 0.7971047
# Bboxes [  0  18 491 702]
# Class ids 39
# Scores 0.5761299
# Bboxes [491 284 272 417]
# Class ids 39
# Scores 0.71191585
# Bboxes [477 315 312 398]
# Class ids 39
# Scores 0.5092647
# Bboxes [483 302 332 418]
# Class ids 0
# Scores 0.5767887
# Bboxes [  0  22 485 634]
# Class ids 0
# Scores 0.7971047
# Bboxes [  0  18 491 702]
# Class ids 39
# Scores 0.5761299
# Bboxes [491 284 272 417]
# Class ids 39
# Scores 0.71191585
# Bboxes [477 315 312 398]
# Class ids 39
# Scores 0.5092647
# Bboxes [483 302 332 418]
# Class ids 0
# Scores 0.6271578
# Bboxes [  0  18 493 643]
# Class ids 0
# Scores 0.6058031
# Bboxes [  0  11 494 709]
# Class ids 39
# Scores 0.6335438
# Bboxes [487 282 278 413]
# Class ids 39
# Scores 0.5098058
# Bboxes [469 321 326 393]
# Class ids 0
# Scores 0.6271578
# Bboxes [  0  18 493 643]
# Class ids 0
# Scores 0.6058031
# Bboxes [  0  11 494 709]
# Class ids 39
# Scores 0.6335438
# Bboxes [487 282 278 413]
# Class ids 39
# Scores 0.5098058
# Bboxes [469 321 326 393]
# Class ids 0
# Scores 0.7502071
# Bboxes [  0  16 489 645]
# Class ids 0
# Scores 0.54455835
# Bboxes [  0  22 493 698]
# Class ids 39
# Scores 0.55131066
# Bboxes [477 325 311 388]
# Class ids 0
# Scores 0.6194802
# Bboxes [488 152 114 161]
# Class ids 0
# Scores 0.74518764
# Bboxes [  0  16 478 645]
# Class ids 0
# Scores 0.50516605
# Bboxes [  0  21 491 699]
# Class ids 39
# Scores 0.5736665
# Bboxes [486 279 284 418]
# Class ids 0
# Scores 0.5853286
# Bboxes [486 152 116 162]
# Class ids 0
# Scores 0.74518764
# Bboxes [  0  16 478 645]
# Class ids 0
# Scores 0.50516605
# Bboxes [  0  21 491 699]
# Class ids 39
# Scores 0.5736665
# Bboxes [486 279 284 418]
# Class ids 0
# Scores 0.5853286
# Bboxes [486 152 116 162]
# Class ids 0
# Scores 0.8019768
# Bboxes [  0  14 484 644]
# Class ids 0
# Scores 0.58103085
# Bboxes [  0  18 490 702]
# Class ids 39
# Scores 0.8454853
# Bboxes [488 309 288 407]
# Class ids 39
# Scores 0.518641
# Bboxes [489 309 314 409]
# Class ids 0
# Scores 0.85133296
# Bboxes [  0  19 480 634]
# Class ids 0
# Scores 0.548718
# Bboxes [  0  23 489 697]
# Class ids 39
# Scores 0.8676427
# Bboxes [486 311 291 403]
# Class ids 39
# Scores 0.5834768
# Bboxes [481 310 334 406]
# Class ids 0
# Scores 0.85133296
# Bboxes [  0  19 480 634]
# Class ids 0
# Scores 0.548718
# Bboxes [  0  23 489 697]
# Class ids 39
# Scores 0.8676427
# Bboxes [486 311 291 403]
# Class ids 39
# Scores 0.5834768
# Bboxes [481 310 334 406]
# Class ids 0
# Scores 0.5276624
# Bboxes [609   0 357 534]
# Class ids 0
# Scores 0.7470981
# Bboxes [  0  18 482 640]
# Class ids 0
# Scores 0.5891775
# Bboxes [  0  25 494 695]
# Class ids 39
# Scores 0.83065873
# Bboxes [485 314 293 400]
# Class ids 0
# Scores 0.64272654
# Bboxes [488 160 123 157]
# Class ids 0
# Scores 0.5483508
# Bboxes [600   0 376 526]
# Class ids 0
# Scores 0.7068095
# Bboxes [  0  19 487 642]
# Class ids 0
# Scores 0.6219203
# Bboxes [  0  26 508 694]
# Class ids 39
# Scores 0.91154134
# Bboxes [493 313 276 402]
# Class ids 0
# Scores 0.5483508
# Bboxes [600   0 376 526]
# Class ids 0
# Scores 0.7068095
# Bboxes [  0  19 487 642]
# Class ids 0
# Scores 0.6219203
# Bboxes [  0  26 508 694]
# Class ids 39
# Scores 0.91154134
# Bboxes [493 313 276 402]
# Class ids 0
# Scores 0.5044938
# Bboxes [637   0 333 536]
# Class ids 0
# Scores 0.65707797
# Bboxes [  0  19 485 643]
# Class ids 0
# Scores 0.5575295
# Bboxes [  0  26 501 694]
# Class ids 39
# Scores 0.91565853
# Bboxes [490 317 285 399]
# Class ids 39
# Scores 0.5776332
# Bboxes [485 315 323 402]
# Class ids 0
# Scores 0.5044938
# Bboxes [637   0 333 536]
# Class ids 0
# Scores 0.65707797
# Bboxes [  0  19 485 643]
# Class ids 0
# Scores 0.5575295
# Bboxes [  0  26 501 694]
# Class ids 39
# Scores 0.91565853
# Bboxes [490 317 285 399]
# Class ids 39
# Scores 0.5776332
# Bboxes [485 315 323 402]
# Class ids 0
# Scores 0.6475912
# Bboxes [639   0 342 529]
# Class ids 0
# Scores 0.6347808
# Bboxes [  0  19 478 646]
# Class ids 0
# Scores 0.8037071
# Bboxes [  0  26 487 694]
# Class ids 39
# Scores 0.9342007
# Bboxes [493 316 278 398]
# Class ids 39
# Scores 0.8605219
# Bboxes [499 312 294 402]
# Class ids 0
# Scores 0.8104927
# Bboxes [601   0 389 526]
# Class ids 0
# Scores 0.61504465
# Bboxes [  1  20 466 640]
# Class ids 0
# Scores 0.5641602
# Bboxes [  0  39 479 678]
# Class ids 39
# Scores 0.92810583
# Bboxes [488 314 286 401]
# Class ids 39
# Scores 0.9044872
# Bboxes [505 308 284 410]
# Class ids 0
# Scores 0.6074272
# Bboxes [486 165 129 155]
# Class ids 0
# Scores 0.8036097
# Bboxes [619   0 366 521]
# Class ids 0
# Scores 0.7753254
# Bboxes [  0  22 484 635]
# Class ids 0
# Scores 0.64562494
# Bboxes [  0  34 501 685]
# Class ids 39
# Scores 0.57739574
# Bboxes [526 314 206 406]
# Class ids 39
# Scores 0.9341786
# Bboxes [486 318 288 398]
# Class ids 39
# Scores 0.91407216
# Bboxes [507 305 283 415]
# Class ids 0
# Scores 0.67010146
# Bboxes [484 164 131 159]
# Class ids 0
# Scores 0.8036097
# Bboxes [619   0 366 521]
# Class ids 0
# Scores 0.7753254
# Bboxes [  0  22 484 635]
# Class ids 0
# Scores 0.64562494
# Bboxes [  0  34 501 685]
# Class ids 39
# Scores 0.57739574
# Bboxes [526 314 206 406]
# Class ids 39
# Scores 0.9341786
# Bboxes [486 318 288 398]
# Class ids 39
# Scores 0.91407216
# Bboxes [507 305 283 415]
# Class ids 0
# Scores 0.67010146
# Bboxes [484 164 131 159]
# Class ids 0
# Scores 0.6551304
# Bboxes [606   0 385 531]
# Class ids 0
# Scores 0.75211203
# Bboxes [  0  20 482 639]
# Class ids 0
# Scores 0.56180143
# Bboxes [  0  31 492 688]
# Class ids 39
# Scores 0.5638481
# Bboxes [519 306 216 414]
# Class ids 39
# Scores 0.9699896
# Bboxes [490 315 280 402]
# Class ids 39
# Scores 0.8374971
# Bboxes [503 310 287 410]
# Class ids 0
# Scores 0.60412675
# Bboxes [616   0 368 528]
# Class ids 0
# Scores 0.56200063
# Bboxes [  1  22 471 647]
# Class ids 0
# Scores 0.629894
# Bboxes [  0  36 490 677]
# Class ids 39
# Scores 0.6213023
# Bboxes [521 313 217 407]
# Class ids 39
# Scores 0.95879424
# Bboxes [485 324 288 390]
# Class ids 39
# Scores 0.9073279
# Bboxes [507 318 282 401]
# Class ids 0
# Scores 0.57583195
# Bboxes [605   7 383 484]
# Class ids 0
# Scores 0.63230425
# Bboxes [  3  23 468 641]
# Class ids 0
# Scores 0.5254211
# Bboxes [  0  43 485 663]
# Class ids 39
# Scores 0.77976084
# Bboxes [521 322 220 398]
# Class ids 39
# Scores 0.9573348
# Bboxes [486 331 287 382]
# Class ids 39
# Scores 0.8872001
# Bboxes [502 327 290 393]
# Class ids 39
# Scores 0.57252395
# Bboxes [517 334 228 370]
# Class ids 0
# Scores 0.57583195
# Bboxes [605   7 383 484]
# Class ids 0
# Scores 0.63230425
# Bboxes [  3  23 468 641]
# Class ids 0
# Scores 0.5254211
# Bboxes [  0  43 485 663]
# Class ids 39
# Scores 0.77976084
# Bboxes [521 322 220 398]
# Class ids 39
# Scores 0.9573348
# Bboxes [486 331 287 382]
# Class ids 39
# Scores 0.8872001
# Bboxes [502 327 290 393]
# Class ids 39
# Scores 0.57252395
# Bboxes [517 334 228 370]
# Class ids 0
# Scores 0.5299275
# Bboxes [597   6 393 486]
# Class ids 0
# Scores 0.613618
# Bboxes [  0  23 474 640]
# Class ids 0
# Scores 0.50333345
# Bboxes [  0  43 489 664]
# Class ids 39
# Scores 0.8594797
# Bboxes [519 315 219 405]
# Class ids 39
# Scores 0.9752494
# Bboxes [486 330 287 381]
# Class ids 39
# Scores 0.9403805
# Bboxes [504 326 287 393]
# Class ids 39
# Scores 0.7444246
# Bboxes [515 332 232 381]
# Class ids 0
# Scores 0.5612319
# Bboxes [  7  29 459 634]
# Class ids 0
# Scores 0.5763196
# Bboxes [  0  35 495 678]
# Class ids 39
# Scores 0.7201709
# Bboxes [518 321 221 399]
# Class ids 39
# Scores 0.9562654
# Bboxes [478 334 299 377]
# Class ids 39
# Scores 0.890969
# Bboxes [493 330 317 390]
# Class ids 0
# Scores 0.6591477
# Bboxes [  8  26 449 641]
# Class ids 0
# Scores 0.6533594
# Bboxes [  0  38 478 671]
# Class ids 39
# Scores 0.8984915
# Bboxes [518 328 221 392]
# Class ids 39
# Scores 0.94217795
# Bboxes [480 339 294 370]
# Class ids 39
# Scores 0.75735354
# Bboxes [491 335 321 382]
# Class ids 39
# Scores 0.6846507
# Bboxes [516 341 225 371]
# Class ids 0
# Scores 0.67612326
# Bboxes [  6  27 452 634]
# Class ids 0
# Scores 0.69716114
# Bboxes [  0  43 487 661]
# Class ids 39
# Scores 0.86472815
# Bboxes [518 326 220 394]
# Class ids 39
# Scores 0.926089
# Bboxes [477 336 298 375]
# Class ids 39
# Scores 0.8942369
# Bboxes [494 334 317 382]
# Class ids 0
# Scores 0.6183768
# Bboxes [481 190 154 149]
# Class ids 39
# Scores 0.61274916
# Bboxes [523 338 214 374]
# Class ids 0
# Scores 0.62770194
# Bboxes [  7  23 446 647]
# Class ids 0
# Scores 0.75218743
# Bboxes [  0  40 478 667]
# Class ids 39
# Scores 0.90283227
# Bboxes [520 320 219 400]
# Class ids 39
# Scores 0.96511894
# Bboxes [479 334 296 376]
# Class ids 39
# Scores 0.9083729
# Bboxes [499 334 301 379]
# Class ids 0
# Scores 0.51360935
# Bboxes [482 191 154 151]
# Class ids 39
# Scores 0.7495958
# Bboxes [520 335 220 381]
# Class ids 0
# Scores 0.62770194
# Bboxes [  7  23 446 647]
# Class ids 0
# Scores 0.75218743
# Bboxes [  0  40 478 667]
# Class ids 39
# Scores 0.90283227
# Bboxes [520 320 219 400]
# Class ids 39
# Scores 0.96511894
# Bboxes [479 334 296 376]
# Class ids 39
# Scores 0.9083729
# Bboxes [499 334 301 379]
# Class ids 0
# Scores 0.51360935
# Bboxes [482 191 154 151]
# Class ids 39
# Scores 0.7495958
# Bboxes [520 335 220 381]
# Class ids 0
# Scores 0.59100235
# Bboxes [536   0 412 509]
# Class ids 0
# Scores 0.5429803
# Bboxes [ 12  14 440 664]
# Class ids 0
# Scores 0.72283554
# Bboxes [  0  38 476 669]
# Class ids 39
# Scores 0.8780444
# Bboxes [511 322 234 398]
# Class ids 39
# Scores 0.9774768
# Bboxes [478 336 295 374]
# Class ids 39
# Scores 0.8769814
# Bboxes [486 335 334 382]
# Class ids 39
# Scores 0.77054876
# Bboxes [510 334 238 376]
# Class ids 0
# Scores 0.56822616
# Bboxes [  0  39 477 665]
# Class ids 39
# Scores 0.81568146
# Bboxes [503 333 254 387]
# Class ids 39
# Scores 0.9699999
# Bboxes [481 341 297 375]
# Class ids 39
# Scores 0.84706086
# Bboxes [479 337 344 381]
# Class ids 39
# Scores 0.775044
# Bboxes [507 342 248 371]
# Class ids 0
# Scores 0.9600827
# Bboxes [  2  55 479 642]
# Class ids 0
# Scores 0.7068929
# Bboxes [ 14  57 498 638]
# Class ids 39
# Scores 0.9393403
# Bboxes [503 358 253 362]
# Class ids 39
# Scores 0.93432295
# Bboxes [474 369 297 351]
# Class ids 39
# Scores 0.6746864
# Bboxes [479 357 347 363]
# Class ids 39
# Scores 0.55460274
# Bboxes [507 356 245 356]
# Class ids 39
# Scores 0.95374775
# Bboxes [511 371 238 349]
# Class ids 0
# Scores 0.990462
# Bboxes [  0  89 483 598]
# Class ids 0
# Scores 0.66788393
# Bboxes [ 14  78 501 605]
# Class ids 39
# Scores 0.97055364
# Bboxes [508 371 238 349]
# Class ids 39
# Scores 0.7241871
# Bboxes [455 380 322 340]
# Class ids 0
# Scores 0.68003714
# Bboxes [481 230 144 155]
# Class ids 39
# Scores 0.5305608
# Bboxes [511 361 232 348]
# Class ids 39
# Scores 0.9862116
# Bboxes [514 372 228 348]
# Class ids 39
# Scores 0.58551383
# Bboxes [523 380 236 340]
# Class ids 0
# Scores 0.9916015
# Bboxes [  0  89 492 596]
# Class ids 0
# Scores 0.78922826
# Bboxes [ 11  78 506 607]
# Class ids 39
# Scores 0.98408145
# Bboxes [508 372 237 348]
# Class ids 39
# Scores 0.7822494
# Bboxes [458 385 311 335]
# Class ids 0
# Scores 0.75269824
# Bboxes [479 233 130 157]
# Class ids 39
# Scores 0.5122906
# Bboxes [504 368 244 334]
# Class ids 39
# Scores 0.9892674
# Bboxes [507 378 236 342]
# Class ids 0
# Scores 0.9916015
# Bboxes [  0  89 492 596]
# Class ids 0
# Scores 0.78922826
# Bboxes [ 11  78 506 607]
# Class ids 39
# Scores 0.98408145
# Bboxes [508 372 237 348]
# Class ids 39
# Scores 0.7822494
# Bboxes [458 385 311 335]
# Class ids 0
# Scores 0.75269824
# Bboxes [479 233 130 157]
# Class ids 39
# Scores 0.5122906
# Bboxes [504 368 244 334]
# Class ids 39
# Scores 0.9892674
# Bboxes [507 378 236 342]
# Class ids 0
# Scores 0.98957556
# Bboxes [  0  90 485 600]
# Class ids 0
# Scores 0.8324361
# Bboxes [ 16  80 498 613]
# Class ids 39
# Scores 0.9828861
# Bboxes [488 387 263 325]
# Class ids 39
# Scores 0.7323645
# Bboxes [444 382 333 338]
# Class ids 0
# Scores 0.5569881
# Bboxes [479 238 118 155]
# Class ids 39
# Scores 0.60844284
# Bboxes [498 381 254 307]
# Class ids 39
# Scores 0.9954637
# Bboxes [504 382 242 338]
# Class ids 0
# Scores 0.98957556
# Bboxes [  0  90 485 600]
# Class ids 0
# Scores 0.8324361
# Bboxes [ 16  80 498 613]
# Class ids 39
# Scores 0.9828861
# Bboxes [488 387 263 325]
# Class ids 39
# Scores 0.7323645
# Bboxes [444 382 333 338]
# Class ids 0
# Scores 0.5569881
# Bboxes [479 238 118 155]
# Class ids 39
# Scores 0.60844284
# Bboxes [498 381 254 307]
# Class ids 39
# Scores 0.9954637
# Bboxes [504 382 242 338]
# Class ids 0
# Scores 0.9648879
# Bboxes [  3  94 477 611]
# Class ids 0
# Scores 0.9148271
# Bboxes [ 17  85 496 618]
# Class ids 39
# Scores 0.9083402
# Bboxes [479 394 279 319]
# Class ids 39
# Scores 0.9009761
# Bboxes [454 364 322 356]
# Class ids 39
# Scores 0.989456
# Bboxes [493 395 259 325]
# Class ids 0
# Scores 0.95294136
# Bboxes [  9 114 450 605]
# Class ids 0
# Scores 0.80906266
# Bboxes [ 29  98 475 622]
# Class ids 39
# Scores 0.91505575
# Bboxes [491 396 258 319]
# Class ids 0
# Scores 0.7660417
# Bboxes [473 269 136 150]
# Class ids 39
# Scores 0.99633026
# Bboxes [500 396 241 324]
# Class ids 39
# Scores 0.6744197
# Bboxes [506 440 238 279]
# Class ids 0
# Scores 0.8877606
# Bboxes [ 20 118 421 597]
# Class ids 0
# Scores 0.7481168
# Bboxes [ 51 101 442 619]
# Class ids 39
# Scores 0.70619786
# Bboxes [486 400 265 318]
# Class ids 0
# Scores 0.596306
# Bboxes [473 277 130 150]
# Class ids 39
# Scores 0.9822154
# Bboxes [497 401 246 319]
# Class ids 39
# Scores 0.74758255
# Bboxes [504 442 237 277]
# Class ids 0
# Scores 0.8520918
# Bboxes [ 19 139 422 562]
# Class ids 0
# Scores 0.5679942
# Bboxes [681  88 276 602]
# Class ids 0
# Scores 0.9795311
# Bboxes [  7 160 450 560]
# Class ids 39
# Scores 0.65041804
# Bboxes [473 414 272 306]
# Class ids 39
# Scores 0.82477885
# Bboxes [511 438 228 282]
# Class ids 0
# Scores 0.67195606
# Bboxes [473 303 141 150]
# Class ids 39
# Scores 0.84179723
# Bboxes [495 429 239 288]
# Class ids 39
# Scores 0.9006929
# Bboxes [499 438 240 282]
# Class ids 0
# Scores 0.5773776
# Bboxes [ 25 153 414 533]
# Class ids 0
# Scores 0.9609562
# Bboxes [  7 168 463 550]
# Class ids 0
# Scores 0.8089256
# Bboxes [ 32 158 473 562]
# Class ids 39
# Scores 0.6558567
# Bboxes [497 448 250 271]
# Class ids 0
# Scores 0.9121733
# Bboxes [471 313 120 148]
# Class ids 39
# Scores 0.52839786
# Bboxes [493 428 238 291]
# Class ids 39
# Scores 0.7692803
# Bboxes [497 446 246 271]
# Class ids 0
# Scores 0.5773776
# Bboxes [ 25 153 414 533]
# Class ids 0
# Scores 0.9609562
# Bboxes [  7 168 463 550]
# Class ids 0
# Scores 0.8089256
# Bboxes [ 32 158 473 562]
# Class ids 39
# Scores 0.6558567
# Bboxes [497 448 250 271]
# Class ids 0
# Scores 0.9121733
# Bboxes [471 313 120 148]
# Class ids 39
# Scores 0.52839786
# Bboxes [493 428 238 291]
# Class ids 39
# Scores 0.7692803
# Bboxes [497 446 246 271]
# Class ids 0
# Scores 0.5047744
# Bboxes [ 31 160 389 520]
# Class ids 0
# Scores 0.9587357
# Bboxes [  9 174 442 546]
# Class ids 0
# Scores 0.7517864
# Bboxes [ 38 162 462 558]
# Class ids 39
# Scores 0.65202665
# Bboxes [493 446 253 274]
# Class ids 0
# Scores 0.6120189
# Bboxes [470 323 141 155]
# Class ids 39
# Scores 0.75896865
# Bboxes [488 452 258 263]
# Class ids 39
# Scores 0.5126199
# Bboxes [483 475 255 245]
# Class ids 39
# Scores 0.5126199
# Bboxes [483 475 255 245]
# Class ids 0
# Scores 0.62830085
# Bboxes [597 262 273 458]
# Class ids 0
# Scores 0.5269379
# Bboxes [ 52 386 507 334]
# Class ids 0
# Scores 0.71459895
# Bboxes [652 326 298 394]
# Class ids 0
# Scores 0.5269379
# Bboxes [ 52 386 507 334]
# Class ids 0
# Scores 0.71459895
# Bboxes [652 326 298 394]
# Class ids 0
# Scores 0.7164408
# Bboxes [ 44 423 512 284]
# Class ids 0
# Scores 0.89697605
# Bboxes [670 357 317 359]
# Class ids 0
# Scores 0.52194947
# Bboxes [473 540 120 159]
# Class ids 0
# Scores 0.68964285
# Bboxes [ 36 380 389 337]
# Class ids 0
# Scores 0.8661828
# Bboxes [ 45 398 497 315]
# Class ids 0
# Scores 0.6688925
# Bboxes [589 322 323 396]
# Class ids 0
# Scores 0.5010687
# Bboxes [648 334 298 383]
# Class ids 0
# Scores 0.68964285
# Bboxes [ 36 380 389 337]
# Class ids 0
# Scores 0.8661828
# Bboxes [ 45 398 497 315]
# Class ids 0
# Scores 0.6688925
# Bboxes [589 322 323 396]
# Class ids 0
# Scores 0.5010687
# Bboxes [648 334 298 383]
# Class ids 0
# Scores 0.9360774
# Bboxes [ 12 361 419 359]
# Class ids 0
# Scores 0.7043134
# Bboxes [ 53 370 443 350]
# Class ids 0
# Scores 0.76287687
# Bboxes [663 306 311 414]
# Class ids 0
# Scores 0.6639735
# Bboxes [471 502 134 163]
# Class ids 0
# Scores 0.9360774
# Bboxes [ 12 361 419 359]
# Class ids 0
# Scores 0.7043134
# Bboxes [ 53 370 443 350]
# Class ids 0
# Scores 0.76287687
# Bboxes [663 306 311 414]
# Class ids 0
# Scores 0.6639735
# Bboxes [471 502 134 163]
# Class ids 0
# Scores 0.6943773
# Bboxes [1002  172  270  548]
# Class ids 0
# Scores 0.9211414
# Bboxes [ 26 365 396 355]
# Class ids 0
# Scores 0.7856505
# Bboxes [ 49 373 454 344]
# Class ids 0
# Scores 0.63777417
# Bboxes [663 310 306 410]
# Class ids 0
# Scores 0.6943773
# Bboxes [1002  172  270  548]
# Class ids 0
# Scores 0.9211414
# Bboxes [ 26 365 396 355]
# Class ids 0
# Scores 0.7856505
# Bboxes [ 49 373 454 344]
# Class ids 0
# Scores 0.63777417
# Bboxes [663 310 306 410]
# Class ids 0
# Scores 0.59677833
# Bboxes [993 169 281 551]
# Class ids 0
# Scores 0.862429
# Bboxes [ 34 357 401 363]
# Class ids 0
# Scores 0.88483477
# Bboxes [ 60 366 436 352]
# Class ids 0
# Scores 0.59989274
# Bboxes [653 316 324 402]
# Class ids 0
# Scores 0.82545763
# Bboxes [ 39 351 398 369]
# Class ids 0
# Scores 0.92586374
# Bboxes [ 66 362 422 356]
# Class ids 0
# Scores 0.6126671
# Bboxes [985 165 294 555]
# Class ids 0
# Scores 0.9308152
# Bboxes [ 17 366 404 354]
# Class ids 0
# Scores 0.7063649
# Bboxes [ 46 373 463 345]
# Class ids 39
# Scores 0.5102621
# Bboxes [551 602 152 117]
# Class ids 0
# Scores 0.94592005
# Bboxes [ 20 363 424 357]
# Class ids 0
# Scores 0.8822673
# Bboxes [ 52 368 446 350]
# Class ids 39
# Scores 0.5130178
# Bboxes [549 601 155 117]
# Class ids 0
# Scores 0.7123066
# Bboxes [983 171 297 549]
# Class ids 0
# Scores 0.917767
# Bboxes [ 22 362 419 358]
# Class ids 0
# Scores 0.84963626
# Bboxes [ 51 367 455 350]
# Class ids 0
# Scores 0.7123066
# Bboxes [983 171 297 549]
# Class ids 0
# Scores 0.917767
# Bboxes [ 22 362 419 358]
# Class ids 0
# Scores 0.84963626
# Bboxes [ 51 367 455 350]
# Class ids 0
# Scores 0.62783074
# Bboxes [968 168 312 552]
# Class ids 0
# Scores 0.9254408
# Bboxes [ 29 357 407 363]
# Class ids 0
# Scores 0.88163257
# Bboxes [ 55 366 443 349]
# Class ids 0
# Scores 0.62783074
# Bboxes [968 168 312 552]
# Class ids 0
# Scores 0.9254408
# Bboxes [ 29 357 407 363]
# Class ids 0
# Scores 0.88163257
# Bboxes [ 55 366 443 349]
# Class ids 0
# Scores 0.8842504
# Bboxes [ 35 357 407 362]
# Class ids 0
# Scores 0.92675453
# Bboxes [ 61 366 430 349]
# Class ids 0
# Scores 0.51745784
# Bboxes [947 176 333 544]
# Class ids 0
# Scores 0.9173248
# Bboxes [ 32 356 405 363]
# Class ids 0
# Scores 0.84497035
# Bboxes [ 60 363 428 352]
# Class ids 0
# Scores 0.76574486
# Bboxes [607 299 277 421]
# Class ids 39
# Scores 0.52665156
# Bboxes [547 600 158 118]
# Class ids 0
# Scores 0.9004636
# Bboxes [ 17 354 439 366]
# Class ids 0
# Scores 0.9159889
# Bboxes [ 49 362 457 355]
# Class ids 0
# Scores 0.6288299
# Bboxes [606 303 281 417]
# Class ids 0
# Scores 0.63974327
# Bboxes [473 490 137 162]
# Class ids 0
# Scores 0.9004636
# Bboxes [ 17 354 439 366]
# Class ids 0
# Scores 0.9159889
# Bboxes [ 49 362 457 355]
# Class ids 0
# Scores 0.6288299
# Bboxes [606 303 281 417]
# Class ids 0
# Scores 0.63974327
# Bboxes [473 490 137 162]
# Class ids 0
# Scores 0.9004636
# Bboxes [ 17 354 439 366]
# Class ids 0
# Scores 0.9159889
# Bboxes [ 49 362 457 355]
# Class ids 0
# Scores 0.6288299
# Bboxes [606 303 281 417]
# Class ids 0
# Scores 0.63974327
# Bboxes [473 490 137 162]
# Class ids 0
# Scores 0.8698187
# Bboxes [ 21 360 427 360]
# Class ids 0
# Scores 0.8781654
# Bboxes [ 48 369 468 346]
# Class ids 0
# Scores 0.8388492
# Bboxes [617 306 273 414]
# Class ids 0
# Scores 0.5795035
# Bboxes [656 316 261 398]
# Class ids 0
# Scores 0.5496119
# Bboxes [473 491 156 161]
# Class ids 0
# ...
# Class ids 0
# Scores 0.5178459
# Bboxes [  0 442 330 277]
# Class ids 0
# Scores 0.5836747
# Bboxes [537 393 239 327]
# Class ids 0
# Scores 0.5240905
# Bboxes [  0 424 333 294]
# Class ids 0
# Scores 0.8735016
# Bboxes [766 321 381 388]
# Class ids 0
# Scores 0.5178459
# Bboxes [  0 442 330 277]
# Class ids 0
# Scores 0.5836747
# Bboxes [537 393 239 327]
# Class ids 0
# Scores 0.9314664
# Bboxes [768 321 381 389]
# Class ids 0
# Scores 0.5045433
# Bboxes [535 393 248 327]
# Class ids 0
# Scores 0.5651299
# Bboxes [  0 424 333 294]
# Class ids 0
# Scores 0.9147235
# Bboxes [763 319 409 392]
# Class ids 0
# Scores 0.6296851
# Bboxes [  0 443 327 275]
# Class ids 0
# Scores 0.5651757
# Bboxes [534 394 248 326]
# Class ids 0
# Scores 0.5651299
# Bboxes [  0 424 333 294]
# Class ids 0
# Scores 0.9147235
# Bboxes [763 319 409 392]
# Class ids 0
# Scores 0.6296851
# Bboxes [  0 443 327 275]
# Class ids 0
# Scores 0.5651757
# Bboxes [534 394 248 326]
# Class ids 0
# Scores 0.93405163
# Bboxes [760 322 412 388]
# Class ids 0
# Scores 0.57048184
# Bboxes [  0 443 327 274]
# Class ids 0
# Scores 0.93405163
# Bboxes [760 322 412 388]
# Class ids 0
# Scores 0.57048184
# Bboxes [  0 443 327 274]
# Class ids 0
# Scores 0.9354559
# Bboxes [762 315 397 399]
# Class ids 0
# Scores 0.5848506
# Bboxes [  0 444 323 272]
# Class ids 0
# Scores 0.93412465
# Bboxes [764 314 400 398]
# Class ids 0
# Scores 0.53708017
# Bboxes [  0 445 330 271]
# Class ids 0
# Scores 0.51196426
# Bboxes [534 394 250 326]
# Class ids 0
# Scores 0.93412465
# Bboxes [764 314 400 398]
# Class ids 0
# Scores 0.53708017
# Bboxes [  0 445 330 271]
# Class ids 0
# Scores 0.51196426
# Bboxes [534 394 250 326]
# Class ids 0
# Scores 0.9205449
# Bboxes [761 316 399 398]
# Class ids 0
# Scores 0.63382095
# Bboxes [  3 442 310 276]
# Class ids 0
# Scores 0.6248551
# Bboxes [536 392 245 328]
# Class ids 0
# Scores 0.9205449
# Bboxes [761 316 399 398]
# Class ids 0
# Scores 0.63382095
# Bboxes [  3 442 310 276]
# Class ids 0
# Scores 0.6248551
# Bboxes [536 392 245 328]
# Class ids 0
# Scores 0.9393275
# Bboxes [756 317 403 395]
# Class ids 0
# Scores 0.6117571
# Bboxes [  2 444 318 273]
# Class ids 0
# Scores 0.52946645
# Bboxes [537 391 250 329]
# Class ids 0
# Scores 0.9393275
# Bboxes [756 317 403 395]
# Class ids 0
# Scores 0.6117571
# Bboxes [  2 444 318 273]
# Class ids 0
# Scores 0.52946645
# Bboxes [537 391 250 329]
# Class ids 0
# Scores 0.5572913
# Bboxes [  1 424 327 295]
# Class ids 0
# Scores 0.92831534
# Bboxes [756 316 401 399]
# Class ids 0
# Scores 0.57994276
# Bboxes [  0 441 322 278]
# Class ids 0
# Scores 0.63564736
# Bboxes [539 392 247 328]
# Class ids 0
# Scores 0.9169647
# Bboxes [764 319 401 394]
# Class ids 0
# Scores 0.56382716
# Bboxes [  2 442 319 275]
# Class ids 0
# Scores 0.68247473
# Bboxes [540 395 238 325]
# Class ids 0
# Scores 0.9169647
# Bboxes [764 319 401 394]
# Class ids 0
# Scores 0.56382716
# Bboxes [  2 442 319 275]
# Class ids 0
# Scores 0.68247473
# Bboxes [540 395 238 325]
# Class ids 0
# Scores 0.6323719
# Bboxes [  4 424 314 292]
# Class ids 0
# Scores 0.6571436
# Bboxes [532 404 249 316]
# Class ids 0
# Scores 0.9522197
# Bboxes [760 317 408 395]
# Class ids 0
# Scores 0.5942547
# Bboxes [  0 443 311 275]
# Class ids 0
# Scores 0.73357975
# Bboxes [539 397 242 321]
# Class ids 0
# Scores 0.5156916
# Bboxes [531 406 249 314]
# Class ids 0
# Scores 0.9481709
# Bboxes [759 316 413 398]
# Class ids 0
# Scores 0.6020342
# Bboxes [  3 443 312 275]
# Class ids 0
# Scores 0.65225166
# Bboxes [539 400 241 316]
# Class ids 0
# Scores 0.5156916
# Bboxes [531 406 249 314]
# Class ids 0
# Scores 0.9481709
# Bboxes [759 316 413 398]
# Class ids 0
# Scores 0.6020342
# Bboxes [  3 443 312 275]
# Class ids 0
# Scores 0.65225166
# Bboxes [539 400 241 316]
# Class ids 0
# Scores 0.5228779
# Bboxes [530 406 257 312]
# Class ids 0
# Scores 0.946751
# Bboxes [765 320 405 392]
# Class ids 0
# Scores 0.59758085
# Bboxes [  6 444 305 274]
# Class ids 0
# Scores 0.65646935
# Bboxes [538 399 249 316]
# Class ids 0
# Scores 0.5228779
# Bboxes [530 406 257 312]
# Class ids 0
# Scores 0.946751
# Bboxes [765 320 405 392]
# Class ids 0
# Scores 0.59758085
# Bboxes [  6 444 305 274]
# Class ids 0
# Scores 0.65646935
# Bboxes [538 399 249 316]
# Class ids 0
# Scores 0.51212025
# Bboxes [  2 424 324 295]
# Class ids 0
# Scores 0.63812613
# Bboxes [533 405 251 314]
# Class ids 0
# Scores 0.96713114
# Bboxes [764 316 421 399]
# Class ids 0
# Scores 0.6590294
# Bboxes [  0 440 317 280]
# Class ids 0
# Scores 0.71391577
# Bboxes [537 397 248 321]
# Class ids 0
# Scores 0.56776386
# Bboxes [531 406 258 312]
# Class ids 0
# Scores 0.9652846
# Bboxes [765 318 410 397]
# Class ids 0
# Scores 0.61360246
# Bboxes [  4 443 311 274]
# Class ids 0
# Scores 0.7052817
# Bboxes [537 397 252 319]
# Class ids 0
# Scores 0.56776386
# Bboxes [531 406 258 312]
# Class ids 0
# Scores 0.9652846
# Bboxes [765 318 410 397]
# Class ids 0
# Scores 0.61360246
# Bboxes [  4 443 311 274]
# Class ids 0
# Scores 0.7052817
# Bboxes [537 397 252 319]
# Class ids 0
# Scores 0.5441762
# Bboxes [  3 424 324 294]
# Class ids 0
# Scores 0.55805665
# Bboxes [531 409 252 309]
# Class ids 0
# Scores 0.93653345
# Bboxes [767 314 406 401]
# Class ids 0
# Scores 0.6565139
# Bboxes [  0 440 319 280]
# Class ids 0
# Scores 0.72798884
# Bboxes [536 401 247 315]
# Class ids 0
# Scores 0.5441762
# Bboxes [  3 424 324 294]
# Class ids 0
# Scores 0.55805665
# Bboxes [531 409 252 309]
# Class ids 0
# Scores 0.93653345
# Bboxes [767 314 406 401]
# Class ids 0
# Scores 0.6565139
# Bboxes [  0 440 319 280]
# Class ids 0
# Scores 0.72798884
# Bboxes [536 401 247 315]
# Class ids 0
# Scores 0.71611625
# Bboxes [527 405 265 315]
# Class ids 0
# Scores 0.8785859
# Bboxes [762 317 407 399]
# Class ids 0
# Scores 0.5789909
# Bboxes [  4 442 311 277]
# Class ids 0
# Scores 0.7497288
# Bboxes [534 399 263 321]
# Class ids 0
# Scores 0.71611625
# Bboxes [527 405 265 315]
# Class ids 0
# Scores 0.8785859
# Bboxes [762 317 407 399]
# Class ids 0
# Scores 0.5789909
# Bboxes [  4 442 311 277]
# Class ids 0
# Scores 0.7497288
# Bboxes [534 399 263 321]
# Class ids 0
# Scores 0.7805268
# Bboxes [533 403 267 317]
# Class ids 0
# Scores 0.8487828
# Bboxes [770 312 398 408]
# Class ids 0
# Scores 0.6645641
# Bboxes [  3 443 311 275]
# Class ids 0
# Scores 0.8083926
# Bboxes [544 392 253 328]
# Class ids 0
# Scores 0.562137
# Bboxes [  7 426 319 290]
# Class ids 0
# Scores 0.76188034
# Bboxes [533 398 279 322]
# Class ids 0
# Scores 0.7490966
# Bboxes [773 314 445 403]
# Class ids 0
# Scores 0.6636643
# Bboxes [  1 442 320 276]
# Class ids 0
# Scores 0.74042004
# Bboxes [546 390 255 330]
# Class ids 0
# Scores 0.562137
# Bboxes [  7 426 319 290]
# Class ids 0
# Scores 0.76188034
# Bboxes [533 398 279 322]
# Class ids 0
# Scores 0.7490966
# Bboxes [773 314 445 403]
# Class ids 0
# Scores 0.6636643
# Bboxes [  1 442 320 276]
# Class ids 0
# Scores 0.74042004
# Bboxes [546 390 255 330]
# Class ids 0
# Scores 0.6666796
# Bboxes [533 392 278 328]
# Class ids 0
# Scores 0.6036284
# Bboxes [776 310 430 407]
# Class ids 0
# Scores 0.61439085
# Bboxes [  0 444 327 274]
# Class ids 0
# Scores 0.77378136
# Bboxes [545 388 267 332]
# Class ids 0
# Scores 0.5633514
# Bboxes [774 286 396 423]
# Class ids 16
# Scores 0.5253765
# Bboxes [ 20 423 301 293]
# Class ids 0
# Scores 0.77570695
# Bboxes [535 398 282 322]
# Class ids 0
# Scores 0.60814345
# Bboxes [512 389 381 331]
# Class ids 0
# Scores 0.70243716
# Bboxes [760 293 434 427]
# Class ids 0
# Scores 0.8496569
# Bboxes [544 394 275 326]
# Class ids 0
# Scores 0.5633514
# Bboxes [774 286 396 423]
# Class ids 16
# Scores 0.5253765
# Bboxes [ 20 423 301 293]
# Class ids 0
# Scores 0.77570695
# Bboxes [535 398 282 322]
# Class ids 0
# Scores 0.60814345
# Bboxes [512 389 381 331]
# Class ids 0
# Scores 0.70243716
# Bboxes [760 293 434 427]
# Class ids 0
# Scores 0.8496569
# Bboxes [544 394 275 326]
# Class ids 0
# Scores 0.74200666
# Bboxes [326 422 302 291]
# Class ids 0
# Scores 0.58131015
# Bboxes [552 336 371 377]
# Class ids 0
# Scores 0.56486726
# Bboxes [336 412 272 300]
# Class ids 0
# Scores 0.74200666
# Bboxes [326 422 302 291]
# Class ids 0
# Scores 0.58131015
# Bboxes [552 336 371 377]
# Class ids 0
# Scores 0.56486726
# Bboxes [336 412 272 300]
# Class ids 0
# Scores 0.8108206
# Bboxes [310 411 310 307]
# Class ids 0
# Scores 0.7162684
# Bboxes [222 419 436 286]
# Class ids 0
# Scores 0.8108206
# Bboxes [310 411 310 307]
# Class ids 0
# Scores 0.7162684
# Bboxes [222 419 436 286]
# Class ids 0
# Scores 0.8463571
# Bboxes [325 414 321 304]
# Class ids 0
# Scores 0.7028737
# Bboxes [258 425 439 279]
# Class ids 0
# Scores 0.6681871
# Bboxes [336 407 287 306]
# Class ids 0
# Scores 0.8849758
# Bboxes [328 408 290 310]
# Class ids 0
# Scores 0.5368801
# Bboxes [261 416 387 292]
# Class ids 0
# Scores 0.67417985
# Bboxes [346 397 254 323]
# Class ids 0
# Scores 0.8849758
# Bboxes [328 408 290 310]
# Class ids 0
# Scores 0.5368801
# Bboxes [261 416 387 292]
# Class ids 0
# Scores 0.67417985
# Bboxes [346 397 254 323]
# Class ids 0
# Scores 0.8067104
# Bboxes [322 401 297 317]
# Class ids 0
# Scores 0.67815655
# Bboxes [248 416 402 290]
# Class ids 0
# Scores 0.54616994
# Bboxes [346 390 263 330]
# Class ids 0
# Scores 0.8067104
# Bboxes [322 401 297 317]
# Class ids 0
# Scores 0.67815655
# Bboxes [248 416 402 290]
# Class ids 0
# Scores 0.54616994
# Bboxes [346 390 263 330]
# Class ids 0
# Scores 0.72361594
# Bboxes [344 409 276 307]
# Class ids 0
# Scores 0.7624707
# Bboxes [339 401 290 312]
# Class ids 0
# Scores 0.6841362
# Bboxes [284 414 392 295]
# Class ids 0
# Scores 0.54410285
# Bboxes [355 387 266 333]
# Class ids 0
# Scores 0.7624707
# Bboxes [339 401 290 312]
# Class ids 0
# Scores 0.6841362
# Bboxes [284 414 392 295]
# Class ids 0
# Scores 0.54410285
# Bboxes [355 387 266 333]
# Class ids 0
# Scores 0.7677409
# Bboxes [  0 321 247 399]
# Class ids 0
# Scores 0.58079654
# Bboxes [  0 317 298 403]
# Class ids 0
# Scores 0.7677409
# Bboxes [  0 321 247 399]
# Class ids 0
# Scores 0.58079654
# Bboxes [  0 317 298 403]
# Class ids 0
# Scores 0.50982916
# Bboxes [  9 352 222 353]
# Class ids 0
# Scores 0.5592256
# Bboxes [  6 343 227 377]
# Class ids 0
# Scores 0.50982916
# Bboxes [  9 352 222 353]
# Class ids 0
# Scores 0.5592256
# Bboxes [  6 343 227 377]
# Class ids 0
# Scores 0.75190395
# Bboxes [  0 337 239 382]
# Class ids 0
# Scores 0.5146629
# Bboxes [  0 333 300 381]
# Class ids 0
# Scores 0.5929934
# Bboxes [  0 356 233 353]
# Class ids 0
# Scores 0.5929934
# Bboxes [  0 356 233 353]
# Class ids 0
# Scores 0.64632046
# Bboxes [  0 361 239 339]
# Class ids 0
# Scores 0.64632046
# Bboxes [  0 361 239 339]
# Class ids 0
# Scores 0.68190706
# Bboxes [  0 349 238 356]
# Class ids 0
# Scores 0.73580253
# Bboxes [  8 348 229 366]
# Class ids 0
# Scores 0.68190706
# Bboxes [  0 349 238 356]
# Class ids 0
# Scores 0.73580253
# Bboxes [  8 348 229 366]
# Class ids 0
# Scores 0.6151638
# Bboxes [242  32 945 687]
# Class ids 0
# Scores 0.5934734
# Bboxes [  3 362 236 337]
# Class ids 0
# Scores 0.53139377
# Bboxes [  3 354 236 345]
# Class ids 0
# Scores 0.53139377
# Bboxes [  3 354 236 345]
# Class ids 0
# Scores 0.6724495
# Bboxes [  5 356 230 342]
# Class ids 0
# Scores 0.5149057
# Bboxes [ 21 346 233 354]
# Class ids 0
# Scores 0.6724495
# Bboxes [  5 356 230 342]
# Class ids 0
# Scores 0.5149057
# Bboxes [ 21 346 233 354]
# Class ids 0
# Scores 0.5607276
# Bboxes [452  22 761 698]
# Class ids 0
# Scores 0.51890564
# Bboxes [  3 352 234 346]
# Class ids 0
# Scores 0.51890564
# Bboxes [  3 352 234 346]
# Class ids 0
# Scores 0.69520926
# Bboxes [417  32 772 680]
# Class ids 0
# Scores 0.6272438
# Bboxes [  2 359 239 345]
# Class ids 0
# Scores 0.69520926
# Bboxes [417  32 772 680]
# Class ids 0
# Scores 0.6272438
# Bboxes [  2 359 239 345]
# Class ids 0
# Scores 0.69574213
# Bboxes [443  38 743 676]
# Class ids 0
# Scores 0.6593798
# Bboxes [  0 358 240 347]
# Class ids 0
# Scores 0.5794725
# Bboxes [148 325 429 389]
# Class ids 0
# Scores 0.7110044
# Bboxes [175 317 461 398]
# Class ids 0
# Scores 0.69574213
# Bboxes [443  38 743 676]
# Class ids 0
# Scores 0.6593798
# Bboxes [  0 358 240 347]
# Class ids 0
# Scores 0.5794725
# Bboxes [148 325 429 389]
# Class ids 0
# Scores 0.7110044
# Bboxes [175 317 461 398]
# Class ids 0
# Scores 0.5049132
# Bboxes [138 330 401 382]
# Class ids 0
# Scores 0.5049132
# Bboxes [138 330 401 382]
# Class ids 0
# Scores 0.53450465
# Bboxes [  3 348 232 363]
# Class ids 0
# Scores 0.66226727
# Bboxes [  0 349 234 371]
# Class ids 0
# Scores 0.5814949
# Bboxes [  4 342 233 378]
# Class ids 0
# Scores 0.5814949
# Bboxes [  4 342 233 378]
# Class ids 0
# Scores 0.57911956
# Bboxes [  3 344 224 367]
# Class ids 0
# Scores 0.57911956
# Bboxes [  3 344 224 367]
# Class ids 0
# Scores 0.6338424
# Bboxes [  3 337 223 368]
# Class ids 0
# Scores 0.70799005
# Bboxes [  1 340 230 380]
# Class ids 0
# Scores 0.5896532
# Bboxes [  9 318 206 402]
# Class ids 0
# Scores 0.6338424
# Bboxes [  3 337 223 368]
# Class ids 0
# Scores 0.70799005
# Bboxes [  1 340 230 380]
# Class ids 0
# Scores 0.5896532
# Bboxes [  9 318 206 402]
# Class ids 0
# Scores 0.613877
# Bboxes [  6 346 222 357]
# Class ids 0
# Scores 0.5419323
# Bboxes [  1 342 232 378]
# Class ids 0
# Scores 0.58396673
# Bboxes [  5 323 211 397]
# Class ids 0
# Scores 0.57236844
# Bboxes [447  23 735 692]
# Class ids 0
# Scores 0.73228747
# Bboxes [  1 340 222 364]
# Class ids 0
# Scores 0.72629756
# Bboxes [  0 340 232 379]
# Class ids 0
# Scores 0.7301092
# Bboxes [  3 322 209 398]
# Class ids 0
# Scores 0.57236844
# Bboxes [447  23 735 692]
# Class ids 0
# Scores 0.73228747
# Bboxes [  1 340 222 364]
# Class ids 0
# Scores 0.72629756
# Bboxes [  0 340 232 379]
# Class ids 0
# Scores 0.7301092
# Bboxes [  3 322 209 398]
# Class ids 0
# Scores 0.6925928
# Bboxes [442  24 754 696]
# Class ids 0
# Scores 0.6406249
# Bboxes [  4 347 220 356]
# Class ids 0
# Scores 0.55076617
# Bboxes [  7 320 206 400]
# Class ids 0
# Scores 0.6925928
# Bboxes [442  24 754 696]
# Class ids 0
# Scores 0.6406249
# Bboxes [  4 347 220 356]
# Class ids 0
# Scores 0.55076617
# Bboxes [  7 320 206 400]
# Class ids 0
# Scores 0.5260887
# Bboxes [433  32 777 676]
# Class ids 0
# Scores 0.68080056
# Bboxes [  0 341 220 365]
# Class ids 0
# Scores 0.54610336
# Bboxes [  0 346 236 371]
# Class ids 0
# Scores 0.5823033
# Bboxes [  2 320 206 400]
# Class ids 0
# Scores 0.5078058
# Bboxes [427  45 780 653]
# Class ids 0
# Scores 0.68411505
# Bboxes [  0 342 218 370]
# Class ids 0
# Scores 0.6151817
# Bboxes [  1 316 208 404]
# Class ids 0
# Scores 0.5078058
# Bboxes [427  45 780 653]
# Class ids 0
# Scores 0.68411505
# Bboxes [  0 342 218 370]
# Class ids 0
# Scores 0.6151817
# Bboxes [  1 316 208 404]
# Class ids 0
# Scores 0.56511074
# Bboxes [  6 340 217 365]
# Class ids 0
# Scores 0.5228501
# Bboxes [  6 325 209 395]
# Class ids 0
# Scores 0.6578052
# Bboxes [  8 331 208 385]
# Class ids 0
# Scores 0.5251526
# Bboxes [  8 322 203 398]
# Class ids 0
# Scores 0.6578052
# Bboxes [  8 331 208 385]
# Class ids 0
# Scores 0.5251526
# Bboxes [  8 322 203 398]
# Class ids 0
# Scores 0.6334955
# Bboxes [  7 332 208 380]
# Class ids 0
# Scores 0.6334955
# Bboxes [  7 332 208 380]
# Class ids 0
# Scores 0.5098146
# Bboxes [444  28 756 683]
# Class ids 0
# Scores 0.59805864
# Bboxes [  7 332 210 378]
# Class ids 0
# Scores 0.5219015
# Bboxes [  7 317 200 403]
# Class ids 0
# Scores 0.6635198
# Bboxes [ 10 337 209 372]
# Class ids 0
# Scores 0.62526387
# Bboxes [231 327 391 389]
# Class ids 0
# Scores 0.5672403
# Bboxes [ 10 324 199 396]
# Class ids 0
# Scores 0.6635198
# Bboxes [ 10 337 209 372]
# Class ids 0
# Scores 0.62526387
# Bboxes [231 327 391 389]
# Class ids 0
# Scores 0.5672403
# Bboxes [ 10 324 199 396]
# Class ids 0
# Scores 0.61694527
# Bboxes [448  27 763 693]
# Class ids 0
# Scores 0.6733912
# Bboxes [ 15 341 204 366]
# Class ids 0
# Scores 0.57205766
# Bboxes [227 330 395 385]
# Class ids 0
# Scores 0.5710417
# Bboxes [ 12 325 196 395]
# Class ids 0
# Scores 0.6278516
# Bboxes [ 11 340 202 371]
# Class ids 0
# Scores 0.56235385
# Bboxes [250 330 359 387]
# Class ids 0
# Scores 0.6278516
# Bboxes [ 11 340 202 371]
# Class ids 0
# Scores 0.56235385
# Bboxes [250 330 359 387]
# Class ids 0
# Scores 0.63374794
# Bboxes [444  39 771 673]
# Class ids 0
# Scores 0.72654444
# Bboxes [ 12 342 205 365]
# Class ids 0
# Scores 0.58955026
# Bboxes [ 14 330 194 390]
# Class ids 0
# Scores 0.63374794
# Bboxes [444  39 771 673]
# Class ids 0
# Scores 0.72654444
# Bboxes [ 12 342 205 365]
# Class ids 0
# Scores 0.58955026
# Bboxes [ 14 330 194 390]
# Class ids 0
# Scores 0.5560215
# Bboxes [445  34 758 670]
# Class ids 0
# Scores 0.6742764
# Bboxes [ 12 342 207 363]
# Class ids 0
# Scores 0.765412
# Bboxes [ 11 342 208 364]
# Class ids 0
# Scores 0.5343324
# Bboxes [201 335 426 381]
# Class ids 0
# Scores 0.62170696
# Bboxes [ 12 329 199 391]
# Class ids 0
# Scores 0.765412
# Bboxes [ 11 342 208 364]
# Class ids 0
# Scores 0.5343324
# Bboxes [201 335 426 381]
# Class ids 0
# Scores 0.62170696
# Bboxes [ 12 329 199 391]
# Class ids 0
# Scores 0.75972474
# Bboxes [444  25 754 694]
# Class ids 0
# Scores 0.7348168
# Bboxes [ 10 338 209 376]
# Class ids 0
# Scores 0.6264691
# Bboxes [ 10 328 201 392]
# Class ids 0
# Scores 0.75972474
# Bboxes [444  25 754 694]
# Class ids 0
# Scores 0.7348168
# Bboxes [ 10 338 209 376]
# Class ids 0
# Scores 0.6264691
# Bboxes [ 10 328 201 392]
# Class ids 0
# Scores 0.8443631
# Bboxes [  6 340 214 371]
# Class ids 0
# Scores 0.5415862
# Bboxes [224 329 399 391]
# Class ids 0
# Scores 0.75662225
# Bboxes [  7 334 206 386]
